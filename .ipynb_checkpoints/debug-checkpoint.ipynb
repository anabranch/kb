# %%
# %matplotlib inline

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import programming as p
e = p.Exercise("Bench", 40)
e2 = p.Exercise("KB Swing", 40)
e3 = p.Exercise("Goblet Squat", 44)

# p = e.generate_plan()
# raw = p.raw
# Out:
# {'Dips': 'push', 'Overhead Press': 'push', 'Bench': 'push', 'Pull ups': 'pull', 'Chin Ups': 'pull', 'Zercher Squat': 'squat', 'Goblet Squat': 'squat', 'Deadlift': 'hinge', 'KB Swing': 'hinge', 'KB Snatch': 'hinge'}
# {'Dips': 'push', 'Overhead Press': 'push', 'Bench': 'push', 'Pull ups': 'pull', 'Chin Ups': 'pull', 'Zercher Squat': 'squat', 'Goblet Squat': 'squat', 'Deadlift': 'hinge', 'KB Swing': 'hinge', 'KB Snatch': 'hinge'}
# {'Dips': 'push', 'Overhead Press': 'push', 'Bench': 'push', 'Pull ups': 'pull', 'Chin Ups': 'pull', 'Zercher Squat': 'squat', 'Goblet Squat': 'squat', 'Deadlift': 'hinge', 'KB Swing': 'hinge', 'KB Snatch': 'hinge'}

# %%
f = p.FullPlan([e, e2, e3], 3)

# %%
f.weekly_plan_nl().plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
f.weekly_plan_nl().cumsum().plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
f.weekly_benchmarks()
# Out:
# week_1    0.35
# week_2    0.22
# week_3    0.28
# week_4    0.15
# Name: 21, dtype: float64
# week_1    0.35
# week_2    0.28
# week_3    0.15
# week_4    0.22
# Name: 22, dtype: float64
# week_1    0.28
# week_2    0.35
# week_3    0.15
# week_4    0.22
# Name: 16, dtype: float64
